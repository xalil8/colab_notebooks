# %% [markdown]
# <a href="https://colab.research.google.com/github/xalil8/colab_notebooks/blob/main/logo_big_network.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="")
project = rf.workspace("halil-ozcan").project("logo_det")
dataset = project.version(3).download("yolov5")

# %%
# !git clone https://github.com/ultralytics/yolov5
# %cd yolov5
# %pip install -qr requirements.txt

import torch
from IPython.display import Image, clear_output

# !rm -rf /content/sample_data  #to remove default sample dataset, no need

# %%
# !python train.py --img 1280 --batch-size -1 --epochs 100 --data /content/logo_det-3/data.yaml  --weights yolov5n6.pt
# Out:
# train: weights=yolov5n6.pt, cfg=, data=/content/logo_det-3/data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=100, batch_size=-1, imgsz=1280, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v6.2-185-ge4398cf Python-3.7.14 torch-1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# ...

# %%
# !cp -r /content/yolov5/runs/train/exp2 /content/drive/MyDrive/DIATTACK/logo_train_results/train1280/
